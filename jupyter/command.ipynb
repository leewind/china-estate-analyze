# %%
import json
import pandas as pd

# %%
f = open('city_list.json', 'rb')
text = f.read()
o = json.loads(text)

# %%
arr = []
cmd = 'scrapy crawl ke -a city_name=%s'
index = 0
for city in o['cities']:
    
    if city['city_name'] in ['天津','深圳','马鞍山','上海','芜湖','安庆','泉州','合肥','重庆','福州','北京','厦门','漳州', '广州']:
        continue
    
    index = index + 1
    
    print(cmd % (city['city_name']))
# Out:
# scrapy crawl ke -a city_name=蚌埠
# scrapy crawl ke -a city_name=淮南
# scrapy crawl ke -a city_name=淮北
# scrapy crawl ke -a city_name=铜陵
# scrapy crawl ke -a city_name=桐城
# scrapy crawl ke -a city_name=黄山
# scrapy crawl ke -a city_name=明光
# scrapy crawl ke -a city_name=阜阳
# scrapy crawl ke -a city_name=宿州
# scrapy crawl ke -a city_name=六安
# scrapy crawl ke -a city_name=霍邱
# scrapy crawl ke -a city_name=亳州
# scrapy crawl ke -a city_name=池州
# scrapy crawl ke -a city_name=宣城
# scrapy crawl ke -a city_name=滁州
# scrapy crawl ke -a city_name=宁国
# scrapy crawl ke -a city_name=天长
# scrapy crawl ke -a city_name=莆田
# scrapy crawl ke -a city_name=三明
# scrapy crawl ke -a city_name=永安
# scrapy crawl ke -a city_name=石狮
# scrapy crawl ke -a city_name=南安
# scrapy crawl ke -a city_name=龙海
# scrapy crawl ke -a city_name=南平
# scrapy crawl ke -a city_name=宁德
# scrapy crawl ke -a city_name=龙岩
# scrapy crawl ke -a city_name=建瓯
# scrapy crawl ke -a city_name=邵武
# scrapy crawl ke -a city_name=福安
# ...
